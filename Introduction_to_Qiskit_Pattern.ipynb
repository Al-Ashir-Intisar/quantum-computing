# %% [markdown]
# # Introduction to Qiskit
#
# Reference: This notebook is a modified version of the tutorial from [IBM Quantum Challenge 2024](https://github.com/qiskit-community/ibm-quantum-challenge-2024/blob/main/content/lab_0/lab-0.ipynb)

# %% [markdown]
# # Table of Contents
# * [Getting started](#start)
#   * [Install Qiskit](#install)
#   * [Troubleshoot](#troubleshoot)
# * [Generate a two-qubit Bell state using Qiskit patterns](#generate)
#   * [Step 1: Map circuits and operators](#step-1)
#     * [Exercise 1](#ex-1)
#   * [Step 2: Optimize the circuit](#step-2)
#   * [Step 3: Execute the circuit](#step-3)
#   * [Step 4: Post-process the results](#step-4)
# * [Congratulations](#congrats)

# %% [markdown]
# # Getting Started <a name="start"></a>
# The name "Qiskit" is a general term referring to a collection of software for executing programs on quantum computers. Most notably among these software tools is the open-source Qiskit SDK, and the runtime environment:
#
# 1. Qiskit SDK (Software Development Kit):
# This is the core, open-source component of Qiskit. It provides developers with the tools necessary to create and manipulate quantum circuits, and to interact with quantum systems.
#
# 2. Qiskit Runtime:
# This is the execution environment that allows you to run your quantum programs on actual quantum hardware. Specifically, it enables access to IBM's quantum processing units (QPUs).
#
# In this workshop, we'll gain hands-on experience with the workflow of constructing and executing quantum circuits using both the Qiskit SDK and Qiskit Runtime.

# %% [markdown]
# ## Install Qiskit <a name="install"></a> :
#
# Before we begin our exploration of Qiskit's general workflow, we need to ensure that Qiskit is properly installed in your working environment.
# Qiskit can be used in various settings, including:
#
# - Local Jupyter notebooks
# - Cloud-based platforms (e.g., Google Colab, qBraid)
# - Integrated Development Environments (IDEs)
# - Command line interfaces
#
# Regardless of your chosen environment, installing Qiskit is the first crucial step in our workshop.
#
# For this tutorial, we'll be using the latest Qiskit version 1.2.4. The following cells contain the necessary installation commands. Please run the appropriate command based on your working environment.
#
# If you would prefer to follow a video guide on how to install and run Qiskit *locally* later after this tutorial, [watch this video to walk you through every step of the process](https://www.youtube.com/watch?v=dZWz4Gs_BuI).

# %%
### Install Qiskit SDK 1.0 or later###
# %pip install qiskit

###Install the other required packages as well###
# %pip install qiskit_aer
# %pip install qiskit_ibm_runtime
# %pip install matplotlib
# %pip install pylatexenc
# %pip install qiskit-transpiler-service
# Out:
# Collecting qiskit
#   Using cached qiskit-1.3.2-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.16.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting numpy<3,>=1.17 (from qiskit)
#   Downloading numpy-2.2.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.5 (from qiskit)
#   Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting sympy>=1.3 (from qiskit)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit) (2.9.0.post0)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.4.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit) (4.12.2)
# Collecting symengine<0.14,>=0.11 (from qiskit)
#   Downloading symengine-0.13.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Collecting pbr>=2.0.0 (from stevedore>=3.0.0->qiskit)
#   Using cached pbr-6.1.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.3->qiskit)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: setuptools in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (75.8.0)
# Using cached qiskit-1.3.2-cp39-abi3-win_amd64.whl (6.5 MB)
# Using cached dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading numpy-2.2.3-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------------ --------------------------- 4.2/12.9 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 25.3 MB/s eta 0:00:00
# Using cached rustworkx-0.16.0-cp39-abi3-win_amd64.whl (2.0 MB)
# Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl (43.9 MB)
#    ---------------------------------------- 0.0/43.9 MB ? eta -:--:--
#    ------ --------------------------------- 6.8/43.9 MB 34.9 MB/s eta 0:00:02
#    ------------- -------------------------- 14.4/43.9 MB 36.2 MB/s eta 0:00:01
#    --------------------- ------------------ 23.1/43.9 MB 36.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 31.7/43.9 MB 37.3 MB/s eta 0:00:01
#    ------------------------------------ --- 39.6/43.9 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------  43.8/43.9 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------  43.8/43.9 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------- 43.9/43.9 MB 29.7 MB/s eta 0:00:00
# Using cached stevedore-5.4.0-py3-none-any.whl (49 kB)
# Downloading symengine-0.13.0-cp311-cp311-win_amd64.whl (17.8 MB)
#    ---------------------------------------- 0.0/17.8 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/17.8 MB 15.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 5.2/17.8 MB 11.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.6/17.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.2/17.8 MB 12.3 MB/s eta 0:00:01
#    --------------------------- ------------ 12.3/17.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 16.5/17.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 17.8/17.8 MB 12.8 MB/s eta 0:00:00
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pbr-6.1.1-py2.py3-none-any.whl (108 kB)
# Installing collected packages: mpmath, sympy, symengine, pbr, numpy, dill, stevedore, scipy, rustworkx, qiskit
# Successfully installed dill-0.3.9 mpmath-1.3.0 numpy-2.2.3 pbr-6.1.1 qiskit-1.3.2 rustworkx-0.16.0 scipy-1.15.1 stevedore-5.4.0 symengine-0.13.0 sympy-1.13.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit_aer
#   Downloading qiskit_aer-0.16.1-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_aer) (1.3.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_aer) (2.2.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_aer) (1.15.1)
# Requirement already satisfied: psutil>=5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_aer) (5.9.5)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.4.0)
# Requirement already satisfied: typing-extensions in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_aer) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (75.8.0)
# Downloading qiskit_aer-0.16.1-cp311-cp311-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.5 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.16.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit_ibm_runtime
#   Using cached qiskit_ibm_runtime-0.35.0-py3-none-any.whl.metadata (20 kB)
# Collecting requests>=2.19 (from qiskit_ibm_runtime)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Using cached requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_ibm_runtime) (2.2.3)
# Collecting urllib3>=1.21.1 (from qiskit_ibm_runtime)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Collecting websocket-client>=1.5.1 (from qiskit_ibm_runtime)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Using cached ibm_platform_services-0.59.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic<2.10,>=2.5.0 (from qiskit_ibm_runtime)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit_ibm_runtime) (1.3.2)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.22.0 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Using cached ibm_cloud_sdk_core-3.22.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<2.10,>=2.5.0->qiskit_ibm_runtime)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10,>=2.5.0->qiskit_ibm_runtime)
#   Downloading pydantic_core-2.23.4-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from pydantic<2.10,>=2.5.0->qiskit_ibm_runtime) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.15.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.13.3)
# Requirement already satisfied: dill>=0.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (5.4.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.13.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19->qiskit_ibm_runtime)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19->qiskit_ibm_runtime)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19->qiskit_ibm_runtime)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting cryptography>=1.3 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading cryptography-44.0.1-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached pyspnego-0.11.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting cffi>=1.12 (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm_cloud_sdk_core<4.0.0,>=3.22.0->ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting sspilib>=0.1.0 (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading sspilib-0.2.0-cp311-cp311-win_amd64.whl.metadata (7.5 kB)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_ibm_runtime) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_ibm_runtime) (1.3.0)
# Collecting pycparser (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: setuptools in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit_ibm_runtime) (75.8.0)
# Using cached qiskit_ibm_runtime-0.35.0-py3-none-any.whl (3.2 MB)
# Using cached ibm_platform_services-0.59.1-py3-none-any.whl (340 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 15.2 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
# Downloading cryptography-44.0.1-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 27.0 MB/s eta 0:00:00
# Using cached ibm_cloud_sdk_core-3.22.1-py3-none-any.whl (69 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Using cached pyspnego-0.11.2-py3-none-any.whl (130 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading sspilib-0.2.0-cp311-cp311-win_amd64.whl (564 kB)
#    ---------------------------------------- 0.0/564.8 kB ? eta -:--:--
#    --------------------------------------- 564.8/564.8 kB 18.9 MB/s eta 0:00:00
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: websocket-client, urllib3, sspilib, PyJWT, pydantic-core, pycparser, idna, charset-normalizer, certifi, annotated-types, requests, pydantic, cffi, ibm_cloud_sdk_core, cryptography, pyspnego, ibm-platform-services, requests-ntlm, qiskit_ibm_runtime
# Successfully installed PyJWT-2.10.1 annotated-types-0.7.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 cryptography-44.0.1 ibm-platform-services-0.59.1 ibm_cloud_sdk_core-3.22.1 idna-3.10 pycparser-2.22 pydantic-2.9.2 pydantic-core-2.23.4 pyspnego-0.11.2 qiskit_ibm_runtime-0.35.0 requests-2.32.3 requests-ntlm-1.3.0 sspilib-0.2.0 urllib3-2.3.0 websocket-client-1.8.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.0 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 24.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 17.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
# Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 25.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting pylatexenc
#   Using cached pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136895 sha256=69ea4aa2951d83a5f4670ec40d42ba587c01de1ae0660113718550682d8eb504
#   Stored in directory: c:\users\iamin\appdata\local\pip\cache\wheels\b1\7a\33\9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit-transpiler-service
#   Using cached qiskit_transpiler_service-0.4.14-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: qiskit~=1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit-transpiler-service) (1.3.2)
# Collecting backoff~=2.0 (from qiskit-transpiler-service)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting qiskit-qasm3-import~=0.4 (from qiskit-transpiler-service)
#   Using cached qiskit_qasm3_import-0.5.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests~=2.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit-transpiler-service) (2.32.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (2.2.3)
# Requirement already satisfied: scipy>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.15.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.13.3)
# Requirement already satisfied: dill>=0.3 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (5.4.0)
# Requirement already satisfied: typing-extensions in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.13.0)
# Collecting openqasm3<2.0,>=0.4 (from openqasm3[parser]<2.0,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service)
#   Using cached openqasm3-1.0.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2025.1.31)
# Collecting antlr4-python3-runtime<4.14,>=4.7 (from openqasm3[parser]<2.0,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service)
#   Using cached antlr4_python3_runtime-4.13.2-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from python-dateutil>=2.8.0->qiskit~=1.0->qiskit-transpiler-service) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from stevedore>=3.0.0->qiskit~=1.0->qiskit-transpiler-service) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from sympy>=1.3->qiskit~=1.0->qiskit-transpiler-service) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\iamin\miniconda3\envs\quantum_comp\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit~=1.0->qiskit-transpiler-service) (75.8.0)
# Using cached qiskit_transpiler_service-0.4.14-py3-none-any.whl (30 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached qiskit_qasm3_import-0.5.1-py3-none-any.whl (27 kB)
# Using cached openqasm3-1.0.0-py3-none-any.whl (539 kB)
# Using cached antlr4_python3_runtime-4.13.2-py3-none-any.whl (144 kB)
# Installing collected packages: openqasm3, antlr4-python3-runtime, backoff, qiskit-qasm3-import, qiskit-transpiler-service
# Successfully installed antlr4-python3-runtime-4.13.2 backoff-2.2.1 openqasm3-1.0.0 qiskit-qasm3-import-0.5.1 qiskit-transpiler-service-0.4.14
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# After installing the required packages, you may need to restart the kernel in order to run them.
#
# Now, let's test to make sure everything is working properly. We've provided some very basic Qiskit code for you in the following cell. This code will create a quantum circuit, apply a single gate, and then draw that circuit. Run the cell below to make sure your system is set up properly.

# %%
from qiskit import QuantumCircuit

# Create a new circuit with a single qubit
qc = QuantumCircuit(1)

# Add a Not gate to qubit 0
qc.x(0)

# Return a drawing of the circuit using MatPlotLib ("mpl"). This is the
# last line of the cell, so the drawing appears in the cell output.
qc.draw("mpl")

# %% [markdown]
# You should see something similar to this as an output:
#
# ![NotGate.png](data:image/png;base64,...)

# %% [markdown]
# For the record, you'll probably see this error at the end of installs: `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.`
#
# It is safe to ignore that particular error.
#
# If everything else installed, then you're all set to begin working with Qiskit! In the next section, we'll dive into [creating and running our first quantum program.](#generate)

# %% [markdown]
# ### Troubleshoot <a name="troubleshoot"></a>
#
# Not working quite yet? Let's check your installs and versions to make sure everything is what it should be.

# %%
### CHECK QISKIT VERSION
import qiskit
qiskit.__version__
# Out:
# '1.3.2'

# %% [markdown]
# You should have a Qiskit version higher than v1.0.2 installed. If you see a version lower than that, you'll need to restart your kernel and reinstall the more recent Qiskit version.

# %% [markdown]
# Other common issues could be solved by the following:
#
# *   If you aren't seeing any output, make sure you've run each code cell.
# *   Try restarting your kernel. How you do this varies by the environment you're using.
#
#
# If you're still running into problems, raise your hand and our tutorial TA will come to assist you 😃.
#
#
# If you experience any installation issues later when you explore on your own, check out this [Coding with Qiskit](https://www.youtube.com/watch?v=dZWz4Gs_BuI) video for additional tips, or explore [the documentation](https://docs.quantum.ibm.com/start/install) for help.

# %% [markdown]
# # Generate a two-qubit Bell state using Qiskit patterns <a name="generate"></a>
#
# Our goal in this lab is to generate a two-qubit Bell state using the approach provided by **Qiskit patterns.**
#
# A Qiskit pattern is a four step workflow for setting up, running, and getting results from a quantum computer. This is the workflow designed to help you use utility-scale quantum computers. It works as follows:
#
# 1. Map circuits and operators
# 2. Optimize the circuit
# 3. Execute the circuit
# 4. Post-process the results
#
# ![patterns.svg](data:image/svg+xml;base64,...)

# %%
### Imports

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Step 1: Map circuits and operators <a name="step-1"></a>

# %% [markdown]
# Mapping your problem to circuits and operators is fairly easy when you're only dealing with a handful of qubits, but can get more difficult as you scale up.
#
# Let's start with a fundamental example: constructing a Bell state.
# The Bell state is a quintessential quantum example that demonstrates entanglement between two qubits. Here's how we create it:
#
# 1. Apply a Hadamard gate to qubit 0:
# This puts the qubit into a superposition state.
# 2. Apply a CNOT (Controlled-NOT) gate between qubits 0 and 1:
# This operation entangles our two qubits.
#
# The result of this circuit is that our two qubits become entangled, meaning that when we measure the output, we should expect to see both qubits sharing the same measurement result.
#
# This example serves as a great starting point for understanding how to construct quantum circuits. As we progress through the workshop, we'll build on this foundation to explore more complex quantum operations and algorithms.

# %%
# Create a new circuit with 2 quantum qubits and 2 classical bits for storing measurement results
qc = QuantumCircuit(2, 2)

# Add a Hadamard gate to qubit 0
qc.h(0)

# Perform a CNOT gate on qubit 1, controlled by qubit 0
qc.cx(0, 1)

# Map the output of the two qubits to the two classical measurement bits respectively
qc.measure([0, 1], [0, 1])

# Return a drawing of the circuit using MatPlotLib ("mpl"). This is the
# last line of the cell, so the drawing appears in the cell output.
qc.draw("mpl")

# %% [markdown]
# This will entangle the two qubits such that the combined state becomes:
#
# $$\frac{|00\rangle + |11\rangle}{\sqrt{2}}$$
#
# ### Expected Outcomes:
# For our Bell state, because we've created an entangled state, we expect to see approximately equal probabilities of measuring the two states |00⟩ and |11⟩

# %% [markdown]
# ## Step 2: Optimize the circuit <a name="step-2"></a>

# %% [markdown]
# A Qiskit pattern is the best framework for working with a quantum computer at *utility scale* — the point where quantum computers can perform reliable computations at a scale beyond brute force classical computing methods. These computations can use hundreds of qubits. However, in this intro section, we're only using two qubits. So, that means we do not need to do any work here to optimize the circuit.
#
# To optimize the circuit, we can use the Qiskit transpiler. During transpilation, we can optimally layout our qubits to minimize the required number of gates. To learn more about Qiskit Transpiler, you can check out [this video](https://www.youtube.com/watch?v=MvX5OUK-tbE) and [qiskit documentation](https://docs.quantum.ibm.com/api/qiskit/transpiler). For now, we'll move on to the next step of the pattern - **execution**.

# %% [markdown]
# ## Step 3: Execute the circuit <a name="step-3"></a>

# %% [markdown]
# Now that we've got our quantum circuit all set up -- now comes the fun part! Let's execute the circuit and see what resulting states we end up with. In this step, we'll introduce a powerful tool: Qiskit Runtime.
# Qiskit Runtime provides an efficient way to run quantum circuits on real quantum hardware or advanced simulators. You might be itching to try this on a real quantum computer, but running on actual quantum hardware requires an IBM account, and we are not going to dive into that just yet. For now, we'll stick with a simulator. In our next notebook, we'll also have a chance to see how different simulator behave.
#
# Here's how we'll run our circuit:
#
# 1. **Set up the simulator**: The `AerSimulator` supports a variety of simulation methods and configuration, for this example, we'll just use the default one and use it to run ideal (noise free).
# 2. **Transpile the circuit for the simulator**:  This steps translates our quantum circuit into a language our simulator can understand. It's like converting a recipe to match the appliances in your kitchen.
# 3. **Run the Experiment**: Finally, we run the simulation 1000 times and collect the results.

# %%
# Initialize a simulator object
backend = AerSimulator()
 
# Transpile/Prepare the circuit for the simulator
qc_compiled = transpile(qc, backend)

# Run the simulation 1000 times
job = backend.run(qc_compiled, shots=1000)

# Collect results
result = job.result()
counts = result.get_counts(qc_compiled)
print("Measurement outcomes:", counts)
# Out:
# Measurement outcomes: {'00': 511, '11': 489}

# %% [markdown]
# ## Step 4: Post-process the results <a name="step-4"></a>

# %% [markdown]
# The last step of Qiskit patterns is where we process, analyze, and visualize the results of our job.
#
# There are many ways you can choose to do this. Here we simply visualize the frequency distribution of the measured states

# %%
plot_histogram(counts)

# %% [markdown]
# You *should* see approximately equal counts for the states '00' and '11'. This shows that your circuit is entangled. Great work!

# %% [markdown]
# # Congratulations! 🙌🎊 <a name="congrats"></a>
#
# Congratulations on completing this tutorial on the Qiskit workflow!
# Let's recap what you've accomplished:
#
# 1. You've learned how to follow the Qiskit workflow to set up, optimize, run, and process a quantum circuit.
# 2. You've successfully created a two-qubit Bell state, a fundamental quantum state demonstrating entanglement.
# 3. You've visualized the frequency distribution of your quantum state, confirming the entanglement.
#
# Now that you've mastered the basics, it's time to take your quantum programming skills to the next level😀. In the next part of our tutorial, we'll dive into implementing a real quantum algorithm -- Grover's search -- and see how it demonstrates a quadratic speedup over classical search algorithms.
